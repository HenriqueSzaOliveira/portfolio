# %%
# %sql
drop table if exists raw_table;
create table raw_table (
  id string,
  value array<struct<key:string, value:string>>
);

# %%
# %sql
insert into raw_table values('1', array(struct('date', '123'), struct('value', 'abc')))

# %%
# %sql
select id, value from raw_table
